# %%
import appart_reduction as ar
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
import regression as rg

df_rent = pd.read_csv('../../data/rent.csv', sep=';', encoding='utf-8')
df_rent = df_rent[(df_rent['surface'].notna()) & (df_rent['furnished'].notna())]
df_rent.reset_index(drop=True, inplace=True)

df_rent = rg.filter_numeric_data(df_rent)
df_rent = rg.normalize_data(df_rent)
df_rent
# Out:
#        price   price_m2  furnished   surface  nb_rooms  nb_bedrooms  \
# 0      500.0  55.555556        1.0 -1.464858 -0.588395     -0.34151
# 1      500.0  45.454545        1.0 -1.279589 -0.588395     -0.34151
# 2      500.0  71.428571        1.0 -1.650127 -0.588395     -0.34151
# 3      500.0  50.000000        1.0 -1.372223 -0.588395     -0.34151
# 4      500.0  55.555556        1.0 -1.464858 -0.588395     -0.34151
# ...      ...        ...        ...       ...       ...          ...
# 1093  1500.0  50.000000        1.0  0.480468  1.284086     -0.34151
# 1094  1500.0  33.333333        1.0  1.869986  1.284086     -0.34151
# 1095  1500.0  55.555556        1.0  0.202564  1.284086     -0.34151
# 1096  1500.0  57.692308        1.0  0.109930 -0.588395     -0.34151
# 1097  1500.0  44.117647        1.0  0.851006  1.284086     -0.34151
#
#       nb_bathrooms  floor_number  building_year  elevator  ...  zipcode_75012  \
# ...

# %%
df_rent
# Out:
#        price   price_m2  furnished   surface  nb_rooms  nb_bedrooms  \
# 0      500.0  55.555556        1.0 -1.464858 -0.588395     -0.34151
# 1      500.0  45.454545        1.0 -1.279589 -0.588395     -0.34151
# 2      500.0  71.428571        1.0 -1.650127 -0.588395     -0.34151
# 3      500.0  50.000000        1.0 -1.372223 -0.588395     -0.34151
# 4      500.0  55.555556        1.0 -1.464858 -0.588395     -0.34151
# ...      ...        ...        ...       ...       ...          ...
# 1093  1500.0  50.000000        1.0  0.480468  1.284086     -0.34151
# 1094  1500.0  33.333333        1.0  1.869986  1.284086     -0.34151
# 1095  1500.0  55.555556        1.0  0.202564  1.284086     -0.34151
# 1096  1500.0  57.692308        1.0  0.109930 -0.588395     -0.34151
# 1097  1500.0  44.117647        1.0  0.851006  1.284086     -0.34151
#
#       nb_bathrooms  floor_number  building_year  elevator  ...  zipcode_75012  \
# ...

# %%
zipcode_cols = [col for col in df_rent.columns if col.startswith('zipcode_')]

rg.fit_regression_model(df_rent, 'price', test_size=0.3, features_column=['surface', 'furnished', 'nb_rooms'])
# Out:
# RMSE sur les données de test : 184.24
#
# Coefficients les plus influents :
#  Variable  Coefficient
#   surface   185.388501
# furnished   -97.002170
#  nb_rooms    -3.821770
# (LinearRegression(),
#      Variable  Coefficient
#  0    surface   185.388501
#  1  furnished   -97.002170
#  2   nb_rooms    -3.821770)
